# %%
import pandas as pd
from datetime import datetime 
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel(f"/workspace/Job_based_projects/Data Analyst/British Airways/British_Airlines_review1.xlsx")

# %%
dataset.columns
# Out:
# Index(['Name', 'Date Published', 'review', 'overall rating',
#        'Verified customer', 'type of travel', 'Route', 'Date of Travel',
#        'Seat Type', 'Seat Comfort', 'Cabin Staff Service', 'Food & Beverages',
#        'Inflight Entertainment', 'Ground Service', 'wifi connectivity',
#        'Value For Money', 'Day Published', 'Month Published',
#        'Year Published'],
#       dtype='object')

# %%
dataset["Date Published"]
def date_spliter(date_str):
    dates = date_str.split()
    
    day = dates[0][:-2]
    month = dates[1]
    year =  dates[2]
    return day,month,year
 
dataset[["Day Published", "Month Published", "Year Published"]] = dataset["Date Published"].apply(date_spliter).apply(pd.Series)
dataset.drop(columns=['Date Published','Day Published'])
# Out:
#                    Name                                review  overall rating  \
# 0     Daniel Chinellato      "left me extremely disappointed"               1
# 1        Flora Dogneton          “customer service was awful”               1
# 2           Alex Martyn             "over 2 weeks to respond"               1
# 3             P Jackson  “wholly inadequate customer service”               1
# 4            R Thornton           “the cabin crew were great”               6
# ...                 ...                                   ...             ...
# 2995         Andrew Ray       British Airways customer review               3
# 2996       Paul Nesbitt       British Airways customer review               5
# 2997          Ash Aryan       British Airways customer review               3
# 2998              A Ray       British Airways customer review               2
# 2999              A Ray       British Airways customer review               1
#
#      Verified customer  type of travel                           Route  \
# 0         Not Verified        Business  Berlin to São Paulo via London
# 1         Not Verified  Couple Leisure                 London to Corfu
# 2         Not Verified    Solo Leisure               Toronto to London
# 3             Verified  Couple Leisure        London Gatwick to Verona
# 4             Verified        Business    London Heathrow to Paris CDG
# ...                ...             ...                             ...
# 2995      Not Verified        Business              Istanbul to London
# 2996      Not Verified        Business               Bangkok to London
# 2997      Not Verified        Business           Dublin to London City
# 2998      Not Verified        Business             Sydney to Singapore
# 2999      Not Verified        Business              London to Istanbul
#
#       Date of Travel       Seat Type  Seat Comfort  Cabin Staff Service  ...  \
# 0         March 2024   Economy Class           4.0                  4.0  ...
# 1     September 2023   Economy Class           1.0                  1.0  ...
# 2          July 2024   Economy Class           NaN                  NaN  ...
# 3          June 2024   Economy Class           1.0                  1.0  ...
# 4          June 2024  Business Class           5.0                  5.0  ...
# ...              ...             ...           ...                  ...  ...
# 2995       July 2015  Business Class           4.0                  4.0  ...
# 2996       July 2015  Business Class           4.0                  4.0  ...
# 2997       July 2015     First Class           1.0                  1.0  ...
# 2998       June 2015  Business Class           2.0                  2.0  ...
# 2999       July 2015  Business Class           3.0                  3.0  ...
#
#       Inflight Entertainment  Ground Service  wifi connectivity  \
# 0                        3.0             1.0                3.0
# 1                        NaN             1.0                NaN
# 2                        NaN             NaN                NaN
# 3                        1.0             1.0                1.0
# 4                        NaN             1.0                NaN
# ...                      ...             ...                ...
# 2995                     1.0             3.0                NaN
# 2996                     2.0             4.0                NaN
# 2997                     NaN             2.0                NaN
# 2998                     3.0             2.0                NaN
# 2999                     NaN             1.0                NaN
#
#       Value For Money  Month Published Year Published month of Travel  \
# 0                   2             July           2024           March
# 1                   1             July           2024       September
# 2                   1             July           2024            July
# 3                   1             June           2024            June
# 4                   3             June           2024            June
# ...               ...              ...            ...             ...
# 2995                1             July           2015            July
# 2996                3             July           2015            July
# 2997                1             July           2015            July
# 2998                2             July           2015            June
# 2999                1             July           2015            July
#
#      year of travel       from Route              To Route
# 0              2024           Berlin  São Paulo via London
# 1              2023           London                 Corfu
# 2              2024          Toronto                London
# 3              2024   London Gatwick                Verona
# 4              2024  London Heathrow             Paris CDG
# ...             ...              ...                   ...
# 2995           2015         Istanbul                London
# 2996           2015          Bangkok                London
# 2997           2015           Dublin           London City
# 2998           2015           Sydney             Singapore
# 2999           2015           London              Istanbul
#
# [3000 rows x 21 columns]

# %%
dataset[['month of Travel', 'year of travel']]= dataset['Date of Travel'].str.split(' ', expand=True)
dataset
# Out:
#                    Name  Date Published                                review  \
# 0     Daniel Chinellato   9th July 2024      "left me extremely disappointed"
# 1        Flora Dogneton   5th July 2024          “customer service was awful”
# 2           Alex Martyn   1st July 2024             "over 2 weeks to respond"
# 3             P Jackson  30th June 2024  “wholly inadequate customer service”
# 4            R Thornton  26th June 2024           “the cabin crew were great”
# ...                 ...             ...                                   ...
# 2995         Andrew Ray   9th July 2015       British Airways customer review
# 2996       Paul Nesbitt   9th July 2015       British Airways customer review
# 2997          Ash Aryan   8th July 2015       British Airways customer review
# 2998              A Ray   7th July 2015       British Airways customer review
# 2999              A Ray   7th July 2015       British Airways customer review
#
#       overall rating Verified customer  type of travel  \
# 0                  1      Not Verified        Business
# 1                  1      Not Verified  Couple Leisure
# 2                  1      Not Verified    Solo Leisure
# 3                  1          Verified  Couple Leisure
# 4                  6          Verified        Business
# ...              ...               ...             ...
# 2995               3      Not Verified        Business
# 2996               5      Not Verified        Business
# 2997               3      Not Verified        Business
# 2998               2      Not Verified        Business
# 2999               1      Not Verified        Business
#
#                                Route  Date of Travel       Seat Type  \
# 0     Berlin to São Paulo via London      March 2024   Economy Class
# 1                    London to Corfu  September 2023   Economy Class
# 2                  Toronto to London       July 2024   Economy Class
# 3           London Gatwick to Verona       June 2024   Economy Class
# 4       London Heathrow to Paris CDG       June 2024  Business Class
# ...                              ...             ...             ...
# 2995              Istanbul to London       July 2015  Business Class
# 2996               Bangkok to London       July 2015  Business Class
# 2997           Dublin to London City       July 2015     First Class
# 2998             Sydney to Singapore       June 2015  Business Class
# 2999              London to Istanbul       July 2015  Business Class
#
#       Seat Comfort  ...  Food & Beverages  Inflight Entertainment  \
# 0              4.0  ...               3.0                     3.0
# 1              1.0  ...               NaN                     NaN
# 2              NaN  ...               NaN                     NaN
# 3              1.0  ...               1.0                     1.0
# 4              5.0  ...               3.0                     NaN
# ...            ...  ...               ...                     ...
# 2995           4.0  ...               1.0                     1.0
# 2996           4.0  ...               3.0                     2.0
# 2997           1.0  ...               1.0                     NaN
# 2998           2.0  ...               2.0                     3.0
# 2999           3.0  ...               2.0                     NaN
#
#       Ground Service  wifi connectivity  Value For Money  Day Published  \
# 0                1.0                3.0                2              9
# 1                1.0                NaN                1              5
# 2                NaN                NaN                1              1
# 3                1.0                1.0                1             30
# 4                1.0                NaN                3             26
# ...              ...                ...              ...            ...
# 2995             3.0                NaN                1              9
# 2996             4.0                NaN                3              9
# 2997             2.0                NaN                1              8
# 2998             2.0                NaN                2              7
# 2999             1.0                NaN                1              7
#
#      Month Published Year Published month of Travel year of travel
# 0               July           2024           March           2024
# 1               July           2024       September           2023
# 2               July           2024            July           2024
# 3               June           2024            June           2024
# 4               June           2024            June           2024
# ...              ...            ...             ...            ...
# 2995            July           2015            July           2015
# 2996            July           2015            July           2015
# 2997            July           2015            July           2015
# 2998            July           2015            June           2015
# 2999            July           2015            July           2015
#
# [3000 rows x 21 columns]

# %%
dataset[["from Route", "To Route"]] = dataset["Route"].str.extract(r'(.*?)(?: to | - )(.*)')
dataset
# Out:
#                    Name  Date Published                                review  \
# 0     Daniel Chinellato   9th July 2024      "left me extremely disappointed"
# 1        Flora Dogneton   5th July 2024          “customer service was awful”
# 2           Alex Martyn   1st July 2024             "over 2 weeks to respond"
# 3             P Jackson  30th June 2024  “wholly inadequate customer service”
# 4            R Thornton  26th June 2024           “the cabin crew were great”
# ...                 ...             ...                                   ...
# 2995         Andrew Ray   9th July 2015       British Airways customer review
# 2996       Paul Nesbitt   9th July 2015       British Airways customer review
# 2997          Ash Aryan   8th July 2015       British Airways customer review
# 2998              A Ray   7th July 2015       British Airways customer review
# 2999              A Ray   7th July 2015       British Airways customer review
#
#       overall rating Verified customer  type of travel  \
# 0                  1      Not Verified        Business
# 1                  1      Not Verified  Couple Leisure
# 2                  1      Not Verified    Solo Leisure
# 3                  1          Verified  Couple Leisure
# 4                  6          Verified        Business
# ...              ...               ...             ...
# 2995               3      Not Verified        Business
# 2996               5      Not Verified        Business
# 2997               3      Not Verified        Business
# 2998               2      Not Verified        Business
# 2999               1      Not Verified        Business
#
#                                Route  Date of Travel       Seat Type  \
# 0     Berlin to São Paulo via London      March 2024   Economy Class
# 1                    London to Corfu  September 2023   Economy Class
# 2                  Toronto to London       July 2024   Economy Class
# 3           London Gatwick to Verona       June 2024   Economy Class
# 4       London Heathrow to Paris CDG       June 2024  Business Class
# ...                              ...             ...             ...
# 2995              Istanbul to London       July 2015  Business Class
# 2996               Bangkok to London       July 2015  Business Class
# 2997           Dublin to London City       July 2015     First Class
# 2998             Sydney to Singapore       June 2015  Business Class
# 2999              London to Istanbul       July 2015  Business Class
#
#       Seat Comfort  ...  Ground Service  wifi connectivity  Value For Money  \
# 0              4.0  ...             1.0                3.0                2
# 1              1.0  ...             1.0                NaN                1
# 2              NaN  ...             NaN                NaN                1
# 3              1.0  ...             1.0                1.0                1
# 4              5.0  ...             1.0                NaN                3
# ...            ...  ...             ...                ...              ...
# 2995           4.0  ...             3.0                NaN                1
# 2996           4.0  ...             4.0                NaN                3
# 2997           1.0  ...             2.0                NaN                1
# 2998           2.0  ...             2.0                NaN                2
# 2999           3.0  ...             1.0                NaN                1
#
#       Day Published  Month Published  Year Published month of Travel  \
# 0                 9             July            2024           March
# 1                 5             July            2024       September
# 2                 1             July            2024            July
# 3                30             June            2024            June
# 4                26             June            2024            June
# ...             ...              ...             ...             ...
# 2995              9             July            2015            July
# 2996              9             July            2015            July
# 2997              8             July            2015            July
# 2998              7             July            2015            June
# 2999              7             July            2015            July
#
#      year of travel       from Route              To Route
# 0              2024           Berlin  São Paulo via London
# 1              2023           London                 Corfu
# 2              2024          Toronto                London
# 3              2024   London Gatwick                Verona
# 4              2024  London Heathrow             Paris CDG
# ...             ...              ...                   ...
# 2995           2015         Istanbul                London
# 2996           2015          Bangkok                London
# 2997           2015           Dublin           London City
# 2998           2015           Sydney             Singapore
# 2999           2015           London              Istanbul
#
# [3000 rows x 23 columns]
